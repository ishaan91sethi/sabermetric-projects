# %%
# Import packages
import pandas as pd
import numpy as np
import xgboost as xgb
from lightgbm import LGBMRegressor
import optuna
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# To Do
# -Load in data
# -Create training/cv/test split. Test should likely be in chronological order to avoid any data leakage
# -List of variables for model, both pitch char and non pitch char models
# -Fit initial XGBoost model and take a peek at results to see if things are looking okay
# -Implememt optuna

# %%
full_pitch_df = pd.read_csv("final_pitch_data_new.csv").drop(columns = ["Unnamed: 0"])

# %%
full_pitch_df.head()
# Out:
#   pitch_type   game_date  release_speed  release_pos_x  release_pos_z  \
# 0         FF  2022-04-26           90.6          -1.94           6.53
# 1         FF  2022-04-26           92.6          -1.90           6.39
# 2         FF  2022-04-26           93.0          -2.04           6.42
# 3         FF  2022-04-26           92.2          -1.97           6.43
# 4         CU  2022-04-26           78.8          -2.14           6.48
#
#          player_name  batter  pitcher     events    description  ...  \
# 0  McKenzie, Triston  621493   663474        NaN  called_strike  ...
# 1  McKenzie, Triston  621493   663474        NaN  called_strike  ...
# 2  McKenzie, Triston  621493   663474        NaN           foul  ...
# 3  McKenzie, Triston  621493   663474        NaN           foul  ...
# 4  McKenzie, Triston  621493   663474  field_out  hit_into_play  ...
#
#    events_in_play batted_ball_type fast_pitch_avg_velo delta_diff        rv  \
# 0             out              NaN           92.251064   0.002177 -0.083518
# 1             out              NaN           92.251064   0.018665 -0.083518
# 2             out               fb           92.251064   0.000000  0.000000
# 3             out               pu           92.251064   0.000000  0.000000
# 4             out               fb           92.251064   0.020345 -0.226302
#
#   tto batter_right  p_throws_right  description3       rv2
# 0   1            1               1        strike -0.083516
# 1   1            1               1        strike -0.083516
# 2   1            1               1            fb  0.025442
# 3   1            1               1            pu -0.100858
# 4   1            1               1            fb  0.025442
#
# [5 rows x 87 columns]

# %%
pitch_char_list = ["release_speed", "release_pos_x", "release_pos_z", "release_extension", "pfx_x", "pfx_z", 
                   "release_spin_rate", "fast_pitch_avg_velo"]
location_list = ["plate_x", "plate_z"]
context_list = ["balls", "strikes", "batter_right", "p_throws_right", "sz_top", "sz_bot", "tto"]
# context_list = ["balls", "strikes", "outs_when_up", "batter_right", "p_throws_right", "runner1b", "runner2b", "runner3b", 
#                 "sz_top", "sz_bot", "tto"]

# %%
# # Turn categorical variables (stand and p_throws) into binary variables
# full_pitch_df["batter_right"] = (full_pitch_df["stand"] == "R").replace({True: 1, False: 0})
# full_pitch_df["p_throws_right"] = (full_pitch_df["p_throws"] == "R").replace({True: 1, False: 0})
# #full_pitch_df[context_list]

# %%
# # One last data filter. No 3 strike or 4 ball pitches
# full_pitch_df = full_pitch_df[(full_pitch_df["balls"] != 4) & (full_pitch_df["strikes"] != 3)]

# %%
# Sort for train/cv/test split
full_pitch_df = full_pitch_df.sort_values(["game_date", "game_pk", "pitcher", "at_bat_number", "pitch_number"])

# %%
# Split by pitch grouping

# Fastball pitches
fb_pitch_type = ["SI", "FC", "FF"]

# Offspeed pitches
ofs_pitch_type = ["FS", "CH", "EP", "FA", "KN"]

# Breaking ball pitches
bb_pitch_type = ["SL", "ST", "CU", "KC", "CS"]

fb_df = full_pitch_df[full_pitch_df["pitch_type"].isin(fb_pitch_type) & (full_pitch_df["p_throws_right"] == 1) & (full_pitch_df["batter_right"] == 1)]
ofs_df = full_pitch_df[full_pitch_df["pitch_type"].isin(ofs_pitch_type)]
bb_df = full_pitch_df[full_pitch_df["pitch_type"].isin(bb_pitch_type)]

# %%
# Start with fastball model
fb_train_df = fb_df.iloc[0:round(len(fb_df) * 0.64), :]
fb_cv_df = fb_df.iloc[(round(len(fb_df) * 0.64)):round(len(fb_df) * 0.8), :]
fb_test_df = fb_df.iloc[(round(len(fb_df) * 0.8)):, :]
(len(fb_train_df) + len(fb_cv_df) + len(fb_test_df)) == len(fb_df)
# Out:
# True

# %%
# Establish hyperparameter range
def fb_objective(trial):
    
    xgb_fit = xgb.XGBRegressor(n_estimators = int(trial.suggest_float("n_estimators", 10, 500, step = 1)), 
                               max_depth = int(trial.suggest_float("max_depth", 3, 10, step = 1)),
                               learning_rate = trial.suggest_float("learning_rate", 0.005, 0.3), 
                               subsample = trial.suggest_float("subsample", 0.6, 1),
                               tree_method = "hist",
                               alpha = trial.suggest_float("alpha", 0, 1))
    
    xgb_fit.fit(fb_train_df[pitch_char_list + location_list + context_list], fb_train_df["rv2"])
    
    pred = xgb_fit.predict(fb_cv_df[pitch_char_list + location_list + context_list])
    fb_cv_df.loc[:,"pred"] = pred
    return((np.mean((pred - fb_cv_df["rv2"])**2))**0.5)

# %%
(np.mean((fb_cv_df["rv2"].mean() - fb_cv_df["rv"])**2))**0.5
# Out:
# 0.20244387332178093

# %%
fb_train_df["rv2"].isna().sum()
# Out:
# 0

# %%
import time
start_time = time.time()
fb_study = optuna.create_study()
 # The optimization finishes after evaluating 1000 times or 3 seconds.
fb_study.optimize(fb_objective, n_trials = 100)
print(time.time() - start_time)
# Out:
# [I 2024-01-05 11:31:15,040] A new study created in memory with name: no-name-386b2b20-0181-497b-ae77-1d6c44935656
# C:\Users\ishaa\AppData\Local\Temp\ipykernel_83508\3722166115.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fb_cv_df.loc[:,"pred"] = pred
# [I 2024-01-05 11:31:23,151] Trial 0 finished with value: 0.07368556801451731 and parameters: {'n_estimators': 464.0, 'max_depth': 3.0, 'learning_rate': 0.2653239806895287, 'subsample': 0.8010216849977206, 'alpha': 0.875344741142457}. Best is trial 0 with value: 0.07368556801451731.
# C:\Users\ishaa\AppData\Local\Temp\ipykernel_83508\3722166115.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fb_cv_df.loc[:,"pred"] = pred
# [I 2024-01-05 11:31:31,735] Trial 1 finished with value: 0.07369870783137919 and parameters: {'n_estimators': 448.0, 'max_depth': 4.0, 'learning_rate': 0.16447725114546805, 'subsample': 0.7074498412349972, 'alpha': 0.021588974197367716}. Best is trial 0 with value: 0.07368556801451731.
# C:\Users\ishaa\AppData\Local\Temp\ipykernel_83508\3722166115.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fb_cv_df.loc[:,"pred"] = pred
# [I 2024-01-05 11:31:57,850] Trial 2 finished with value: 0.07915868063773591 and parameters: {'n_estimators': 403.0, 'max_depth': 9.0, 'learning_rate': 0.25098880233110465, 'subsample': 0.8032737985145542, 'alpha': 0.14584164073008066}. Best is trial 0 with value: 0.07368556801451731.
# C:\Users\ishaa\AppData\Local\Temp\ipykernel_83508\3722166115.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fb_cv_df.loc[:,"pred"] = pred
# [I 2024-01-05 11:32:11,454] Trial 3 finished with value: 0.07534923691926187 and parameters: {'n_estimators': 434.0, 'max_depth': 8.0, 'learning_rate': 0.007859513451198393, 'subsample': 0.6721443161480432, 'alpha': 0.49741423349688474}. Best is trial 0 with value: 0.07368556801451731.
# C:\Users\ishaa\AppData\Local\Temp\ipykernel_83508\3722166115.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fb_cv_df.loc[:,"pred"] = pred
# [I 2024-01-05 11

# C:\Users\ishaa\AppData\Local\Temp\ipykernel_83508\3722166115.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fb_cv_df.loc[:,"pred"] = pred
# [I 2024-01-05 13:53:36,063] Trial 97 finished with value: 0.07310775873812983 and parameters: {'n_estimators': 461.0, 'max_depth': 8.0, 'learning_rate': 0.021178232690448814, 'subsample': 0.822332331823158, 'alpha': 0.07772653880395072}. Best is trial 89 with value: 0.0730947532352412.
# C:\Users\ishaa\AppData\Local\Temp\ipykernel_83508\3722166115.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fb_cv_df.loc[:,"pred"] = pred
# [I 2024-01-05 13:54:00,564] Trial 98 finished with value: 0.07311191242374677 and parameters: {'n_estimators': 485.0, 'max_depth': 8.0, 'learning_rate': 0.022575750455878896, 'subsample': 0.8204226463165798, 'alpha': 0.08085780806003239}. Best is trial 89 with value: 0.0730947532352412.
# C:\Users\ishaa\AppData\Local\Temp\ipykernel_83508\3722166115.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fb_cv_df.loc[:,"pred"] = pred
# [I 2024-01-05 13:54:20,219] Trial 99 finished with value: 0.07336913273810314 and parameters: {'n_estimators': 453.0, 'max_depth': 8.0, 'learning_rate': 0.010075527110238836, 'subsample': 0.8176654600770503, 'alpha': 0.08352648098745735}. Best is trial 89 with value: 0.0730947532352412.
# 8585.192097187042

# %%
test = fb_cv_df.groupby(["player_name", "pitch_type"]).aggregate({"rv2":"mean", "pred": "mean", "description": "count"})
test2 = test[test["description"] > 50]
print(test2["rv2"].corr(test2["pred"]))
test2.sort_values("pred").sort_values("pred").head(20)
# Out:
# 0.5126793493895159
#                                    rv2      pred  description
# player_name       pitch_type
# Alcantara, Sandy  FF         -0.023626 -0.009678           53
# Foley, Jason      SI         -0.021184 -0.008466           84
# Bassitt, Chris    SI         -0.001775 -0.007397          152
# Clevinger, Mike   FF         -0.004368 -0.007330           53
# Zeuch, T.J.       SI          0.004052 -0.007128           53
# Bundy, Dylan      FF         -0.012432 -0.006473           78
# García, Luis      SI         -0.010232 -0.006435           61
# Webb, Logan       SI         -0.012860 -0.006202           66
# Wheeler, Zack     FF         -0.019520 -0.005829           58
# Mahle, Tyler      FF         -0.014207 -0.005664           80
# Junis, Jakob      SI         -0.009184 -0.005527           87
# López, Pablo      SI         -0.021283 -0.005133           53
# Whitlock, Garrett SI         -0.002918 -0.004916           86
# Brasier, Ryan     FF         -0.018839 -0.004910           55
# Wilson, Bryse     SI          0.012184 -0.004901           76
# Armstrong, Shawn  SI         -0.019421 -0.004497           67
# Darvish, Yu       FC         -0.013338 -0.004453           55
# deGrom, Jacob     FF         -0.004688 -0.004411          104
# Kelly, Merrill    FF         -0.011837 -0.004330           70
# Wilson, Steven    FF         -0.008369 -0.003895           51

# %%
full_pitch_df.columns.tolist()
# Out:
# ['pitch_type',
#  'game_date',
#  'release_speed',
#  'release_pos_x',
#  'release_pos_z',
#  'player_name',
#  'batter',
#  'pitcher',
#  'events',
#  'description',
#  'spin_dir',
#  'game_type',
#  'stand',
#  'p_throws',
#  'home_team',
#  'away_team',
#  'type',
#  'balls',
#  'strikes',
#  'game_year',
#  'pfx_x',
#  'pfx_z',
#  'plate_x',
#  'plate_z',
#  'on_3b',
#  'on_2b',
#  'on_1b',
#  'outs_when_up',
#  'inning',
#  'inning_topbot',
#  'hc_x',
#  'hc_y',
#  'vx0',
#  'vy0',
#  'vz0',
#  'ax',
#  'ay',
#  'az',
#  'sz_top',
#  'sz_bot',
#  'hit_distance_sc',
#  'launch_speed',
#  'launch_angle',
#  'release_spin_rate',
#  'release_extension',
#  'game_pk',
#  'release_pos_y',
#  'estimated_ba_using_speedangle',
#  'estimated_woba_using_speedangle',
#  'woba_value',
#  'woba_denom',
#  'iso_value',
#  'launch_speed_angle',
#  'at_bat_number',
#  'pitch_number',
#  'home_score',
#  'away_score',
#  'bat_score',
#  'fld_score',
#  'post_away_score',
#  'post_home_score',
#  'spin_axis',
#  'delta_run_exp',
#  'inning_top',
#  'inning_id',
#  'runner1b',
#  'runner2b',
#  'runner3b',
#  'state',
#  'runs_end_inning',
#  'runs_rest_inning',
#  'exp_runs',
#  'state_post',
#  'exp_runs_post',
#  'runs_scored',
#  'delta_run_exp2',
#  'description2',
#  'events_in_play',
#  'batted_ball_type',
#  'fast_pitch_avg_velo',
#  'delta_diff',
#  'rv',
#  'tto',
#  'batter_right',
#  'p_throws_right']

# %%
# Let's do some exploration!
full_pitch_df.groupby("pitch_type").aggregate({"rv":"mean", "pitch_number":"count", "delta_run_exp": "mean", "pfx_x": "mean",
                                               "pfx_z": "mean", "release_speed": "mean"}).sort_values("rv")
# Out:
#                   rv  pitch_number  delta_run_exp      pfx_x      pfx_z  \
# pitch_type
# SL         -0.000034        145876      -0.002264   3.669776   1.872354
# ST          0.000205          1273       0.000441  12.833119  -0.880534
# FS          0.001196         10322      -0.003693 -10.868115   3.904022
# CU          0.001426         58696      -0.000111   3.787476  -8.977667
# SI          0.001624        111008       0.000382  -6.374230   8.708303
# KC          0.002408         13945      -0.000128   5.692027 -10.232941
# FC          0.003050         50535       0.000133   1.705080   8.036616
# FF          0.003238        231994       0.000522  -3.127531  16.117360
# CH          0.005010         79995       0.002219  -4.223877   6.199781
# CS          0.027299            95       0.030379   6.544421 -12.865263
# EP          0.032691           492       0.025191  -1.907073  16.477073
# FA          0.045717          1278       0.059905  -6.555962  15.130704
# KN          0.123196            19       0.069158  -2.229474   7.793684
#
#             release_speed
# pitch_type
# SL              84.610533
# ST              81.193480
# FS              87.199341
# CU              79.058815
# SI              93.351740
# KC              81.239104
# FC              88.998148
# FF              93.919448
# CH              85.330018
# CS              67.990526
# EP              50.037398
# FA              68.522222
# KN              55.368421

# %%
# Fastball pitches
fb_pitch_type = ["SI", "FC", "FF"]

# Offspeed pitches
ofs_pitch_type = ["FS", "CH", "EP", "FA", "KN"]

# Breaking ball pitches
bb_pitch_type = ["SL", "ST", "CU", "KC", "CS"]

full_pitch_df["rv"].corr(full_pitch_bdf["delta_run_exp2"])
# Out:
# 0.8122587256811388

# %%
test = full_pitch_df.groupby(["player_name", "pitch_type"]).aggregate({"rv":"mean", "pfx_x":"count"}).reset_index().sort_values("rv")
test[(test["pfx_x"] > 500) & (test["pitch_type"] == "SL")].head(50)
# Out:
#             player_name pitch_type        rv  pfx_x
# 830       Díaz, Edwin O         SL -0.027370    534
# 2139      Muñoz, Andrés         SL -0.026900    661
# 2234     Ohtani, Shohei         SL -0.022211    984
# 700         Darvish, Yu         SL -0.020545    566
# 2669      Scherzer, Max         SL -0.019808    507
# 517        Cease, Dylan         SL -0.018303   1338
# 2123       Murfee, Penn         SL -0.015831    511
# 1459       Jax, Griffin         SL -0.015327    560
# 2636  Sandoval, Patrick         SL -0.013621    711
# 191       Barlow, Scott         SL -0.013607    534
# 2559     Romano, Jordan         SL -0.012460    512
# 492      Castillo, Luis         SL -0.012456    545
# 616   Contreras, Roansy         SL -0.012450    543
# 1455   Javier, Cristian         SL -0.011793    706
# 486     Castillo, Diego         SL -0.011482    528
# 607        Cole, Gerrit         SL -0.010579    738
# 2884   Strider, Spencer         SL -0.010015    643
# 2754      Skubal, Tarik         SL -0.009888    591
# 3300       Wisler, Matt         SL -0.009729    684
# 1543   Kershaw, Clayton         SL -0.009306    786
# 282       Bieber, Shane         SL -0.009219    826
# 1944     McHugh, Collin         SL -0.009085    523
# 2237      Okert, Steven         SL -0.008875    657
# 2818   Springs, Jeffrey         SL -0.008516    533
# 2369      Pivetta, Nick         SL -0.007844    604
# 210       Bass, Anthony         SL -0.007672    548
# 1006    Fulmer, Michael         SL -0.006396    661
# 1178          Gray, Jon         SL -0.005134    744
# 2846     Steele, Justin         SL -0.004959    629
# 3115  Verlander, Justin         SL -0.004946    738
# 1183       Gray, Josiah         SL -0.004827    761
# 610      Coleman, Dylan         SL -0.004698    512
# 120       Archer, Chris         SL -0.004690    791
# 1196     Greene, Hunter         SL -0.004563    899
# 42     Alcantara, Sandy         SL -0.003766    714
# 995          Fried, Max         SL -0.003678    524
# 2895    Stroman, Marcus         SL -0.003407    573
# 2794       Snell, Blake         SL -0.003146    569
# 2541      Rodón, Carlos         SL -0.003088    910
# 1408     Hudson, Dakota         SL -0.002711    603
# 3197        Webb, Logan         SL -0.002095    982
# 1491  Kaprielian, James         SL -0.001689    513
# 1822       Manoah, Alek         SL -0.001121    797
# 467    Carrasco, Carlos         SL -0.000992    581
# 2960   Taillon, Jameson         SL -0.000714    527
# 749       Detmers, Reid         SL -0.000052    557
# 2549     Rogers, Taylor         SL  0.000002    619
# 2379       Plesac, Zach         SL  0.000285    523
# 1480       Junis, Jakob         SL  0.000581    909
# 2749      Singer, Brady         SL  0.000658    903

# %%
#train_df =
train_df = full_pitch_df.iloc[0:round(len(full_pitch_df) * 0.64), :]
cv_df = full_pitch_df.iloc[(round(len(full_pitch_df) * 0.64)):round(len(full_pitch_df) * 0.8), :]
test_df = full_pitch_df.iloc[(round(len(full_pitch_df) * 0.8)):, :]
(len(train_df) + len(cv_df) + len(test_df)) == len(full_pitch_df)
# Out:
# True

# %%
# Initial test model 
xgb_fit = xgb.XGBRegressor(n_estimators = 300, learning_rate = 0.01, max_depth = 5, tree_method = "hist")
xgb_fit.fit(train_df[pitch_char_list + location_list + context_list], train_df["rv"])
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.01, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=5, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              n_estimators=300, n_jobs=None, num_parallel_tree=None,
#              predictor=None, random_state=None, ...)

# %%
SEARCH_PARAMS = {'learning_rate': trial.suggest_uniform("learning_rate", 0.005, 0.3),
                 'max_depth': int(trial.suggest_discrete_uniform("max_depth", 3, 10, 1)),
                 'n_estimators': int(trial.suggest_discrete_uniform("n_estimators", 50, 500, 1)),
                 'lambda_l1':
                 'num_leaves': int(trial.suggest_discrete_uniform("max_depth", 3, 10, 1)),
                 'feature_fraction': trial.suggest_uniform("subsample", 0.5, 0.8),
                 'subsample': trial.suggest_uniform("subsample", 0.5, 0.8)}

FIXED_PARAMS={'objective': 'binary',
             'metric': 'auc',
             'is_unbalance':True,
             'bagging_freq':5,
             'boosting':'dart',
             'early_stopping_rounds':30}

# %%
# Establish hyperparameter range
def objective(trial):
     
    xgb_fit.fit(train_df[pitch_char_list + location_list + context_list], train_df["rv"])
    
    pred = xgb_fit.predict(cv_df[pitch_char_list + location_list + context_list])
    
    return((np.mean((pred - cv_df["rv"])**2))**0.5)

# %%
# Establish hyperparameter range
def objective(trial):
    
    xgb_fit = xgb.XGBRegressor(n_estimators = int(trial.suggest_float("n_estimators", 50, 1000, step = 1)), 
                               max_depth = int(trial.suggest_float("max_depth", 3, 10, step = 1)),
                               learning_rate = trial.suggest_float("learning_rate", 0.005, 0.3), 
                               subsample = trial.suggest_float("subsample", 0.6, 1),
                               tree_method = "hist")
    
    xgb_fit.fit(train_df[pitch_char_list + location_list + context_list], train_df["rv"])
    
    pred = xgb_fit.predict(cv_df[pitch_char_list + location_list + context_list])
    
    return((np.mean((pred - cv_df["rv"])**2))**0.5)

# %%
context_list
# Out:
# ['balls',
#  'strikes',
#  'batter_right',
#  'p_throws_right',
#  'sz_top',
#  'sz_bot',
#  'tto']

# %%
import time
start_time = time.time()
study = optuna.create_study()
 # The optimization finishes after evaluating 1000 times or 3 seconds.
study.optimize(objective, n_trials = 100)
print(time.time() - start_time)
# Out:
# [I 2023-10-23 22:20:28,660] A new study created in memory with name: no-name-127efd14-bdea-4314-a515-09efe2038b05
# [I 2023-10-23 22:21:51,565] Trial 0 finished with value: 0.22149429503091442 and parameters: {'n_estimators': 653.0, 'max_depth': 10.0, 'learning_rate': 0.2885033377933189, 'subsample': 0.7115808180522478}. Best is trial 0 with value: 0.22149429503091442.
# [I 2023-10-23 22:22:56,487] Trial 1 finished with value: 0.1991002454304466 and parameters: {'n_estimators': 604.0, 'max_depth': 10.0, 'learning_rate': 0.05800037986589545, 'subsample': 0.9781486570259706}. Best is trial 1 with value: 0.1991002454304466.
# [I 2023-10-23 22:23:33,999] Trial 2 finished with value: 0.19727358357684313 and parameters: {'n_estimators': 475.0, 'max_depth': 8.0, 'learning_rate': 0.045423481726739885, 'subsample': 0.9250261214736584}. Best is trial 2 with value: 0.19727358357684313.
# [I 2023-10-23 22:23:51,892] Trial 3 finished with value: 0.20481540232052137 and parameters: {'n_estimators': 170.0, 'max_depth': 9.0, 'learning_rate': 0.2955438196688657, 'subsample': 0.8694089055006793}. Best is trial 2 with value: 0.19727358357684313.
# [I 2023-10-23 22:24:52,941] Trial 4 finished with value: 0.20391440427151541 and parameters: {'n_estimators': 777.0, 'max_depth': 8.0, 'learning_rate': 0.17911538922390713, 'subsample': 0.9719762690855318}. Best is trial 2 with value: 0.19727358357684313.
# [I 2023-10-23 22:25:21,055] Trial 5 finished with value: 0.19973465539221244 and parameters: {'n_estimators': 325.0, 'max_depth': 8.0, 'learning_rate': 0.12450791209595133, 'subsample': 0.6146934949847781}. Best is trial 2 with value: 0.19727358357684313.
# [I 2023-10-23 22:25:49,835] Trial 6 finished with value: 0.1995918146902562 and parameters: {'n_estimators': 336.0, 'max_depth': 8.0, 'learning_rate': 0.11624707686186365, 'subsample': 0.6050083564326957}. Best is trial 2 with value: 0.19727358357684313.
# [I 2023-10-23 22:26:30,828] Trial 7 finished with value: 0.19768891391063442 and parameters: {'n_estimators': 719.0, 'max_depth': 5.0, 'learning_rate': 0.11853305171522065, 'subsample': 0.718596770018566}. Best is trial 2 with value: 0.19727358357684313.
# [I 2023-10-23 22:27:15,835] Trial 8 finished with value: 0.1969891323584911 and parameters: {'n_estimators': 757.0, 'max_depth': 5.0, 'learning_rate': 0.027266891191622365, 'subsample': 0.714054364669238}. Best is trial 8 with value: 0.1969891323584911.
# [I 2023-10-23 22:27:56,778] Trial 9 finished with value: 0.1972700783678513 and parameters: {'n_estimators': 777.0, 'max_depth': 4.0, 'learning_rate': 0.0857780485834351, 'subsample': 0.6066553973666382}. Best is trial 8 with value: 0.1969891323584911.
# [I 2023-10-23 22:28:37,076] Trial 10 finished with value: 0.1974178090681365 and parameters: {'n_estimators': 864.0, 'max_depth': 3.0, 'learning_rate': 0.01459849369498836, 'subsample': 0.7840813486574862}. Best is trial 8 with value: 0.1969891323584911.
# [I 2023-10-23 22:34:02,157] Trial 11 finished with value: 0.19706873392270405 and parameters: {'n_estimators': 909.0, 'max_depth': 5.0, 'learning_rate': 0.009169924990457712, 'subsample': 0.6735821303903747}. Best is trial 8 with value: 0.1969891323584911.
# [I 2023-10-23 22:35:09,380] Trial 12 finished with value: 0.19693626397188851 and parameters: {'n_estimators': 980.0, 'max_depth': 6.0, 'learning_rate': 0.010322830147936474, 'subsample': 0.6925999989998393}. Best is trial 12 with value: 0.19693626397188851.
# [I 2023-10-23 22:36:15,376] Trial 13 finished with value: 0.19697266342479963 and parameters: {'n_estimators': 982.0, 'max_depth': 6.0, 'learning_rate': 0.006892130723761898, 'subsample': 0.7803578121865644}. Best is trial 12 with value: 0.19693626397188851.
# [I 2023-10-23 22:37:21,200] Trial 14 finished with value: 0.19704258954416926 and parameters: {'n_estimators': 982.0, 'max_depth': 6.0, 'learning_rate': 0.005623468020830476, 'subsample': 0.8186410092838154}. Best is trial 12 with value: 0.19693626397188851.
# [I 2023-10-24 11:10:31,243] Trial 15 finished with value: 0.19764405758780934 and parameters: {'n_estimators': 997.0, 'max_depth': 6.0, 'learning_rate': 0.06283384079988373, 'subsample': 0.7848703839127333}. Best is trial 12 with value: 0.19693626397188851.
# [I 2023-10-24 11:11:53,412] Trial 16 finished with value: 0.19863325119202666 and parameters: {'n_estimators': 884.0, 'max_depth': 7.0, 'learning_rate': 0.0791577256513321, 'subsample': 0.7564865176491333}. Best is trial 12 with value: 0.19693626397188851.
# [I 2023-10-24 11:12:46,428] Trial 17 finished with value: 0.1969985722507025 and parameters: {'n_estimators': 542.0, 'max_depth': 7.0, 'learning_rate': 0.03532527527741159, 'subsample': 0.8504948048661508}. Best is trial 12 with value: 0.19693626397188851.
# [I 2023-10-24 11:12:52,297] Trial 18 finished with value: 0.4263870263510713 and parameters: {'n_estimators': 50.0, 'max_depth': 3.0, 'learning_rate': 0.00555848492181525, 'subsample': 0.6652443450265884}. Best is trial 12 with value: 0.19693626397188851.
# [I 2023-10-24 11:13:54,246] Trial 19 finished with value: 0.19732097355727227 and parameters: {'n_estimators': 878.0, 'max_depth': 6.0, 'learning_rate': 0.04998958416268352, 'subsample': 0.7638220419164277}. Best is trial 12 with value: 0.19693626397188851.
# [I 2023-10-24 11:14:18,094] Trial 20 finished with value: 0.19706319593713154 and parameters: {'n_estimators': 442.0, 'max_depth': 4.0, 'learning_rate': 0.07968620094240256, 'subsample': 0.8298544413054652}. Best is trial 12 with value: 0.19693626397188851.
# [I 2023-10-24 11:15:01,439] Trial 21 finished with value: 0.19702205825519292 and parameters: {'n_estimators': 751.0, 'max_depth': 5.0, 'learning_rate': 0.037821796792622195, 'subsample': 0.7535311097634965}. Best is trial 12 with value: 0.19693626397188851.
# [I 2023-10-24 17:08:28,279] Trial 22 finished with value: 0.19709226993493556 and parameters: {'n_estimators': 955.0, 'max_depth': 4.0, 'learning_rate': 0.02781842132102927, 'subsample': 0.7109435111379094}. Best is trial 12 with value: 0.19693626397188851.
# [I 2023-10-24 17:09:29,089] Trial 23 finished with value: 0.19701138824429318 and parameters: {'n_estimators': 836.0, 'max_depth': 5.0, 'learning_rate': 0.031317744338381324, 'subsample': 0.6695861485454678}. Best is trial 12 with value: 0.19693626397188851.
# [I 2023-10-24 17:10:40,020] Trial 24 finished with value: 0.19695438508230426 and parameters: {'n_estimators': 813.0, 'max_depth': 7.0, 'learning_rate': 0.006725710874477597, 'subsample': 0.7391144836689293}. Best is trial 12 with value: 0.19693626397188851.
# [I 2023-10-24 17:11:55,331] Trial 25 finished with value: 0.19693837008876336 and parameters: {'n_estimators': 927.0, 'max_depth': 7.0, 'learning_rate': 0.00637258049037844, 'subsample': 0.8098614562959332}. Best is trial 12 with value: 0.19693626397188851.
# [I 2023-10-24 17:12:48,051] Trial 26 finished with value: 0.19767271955393448 and parameters: {'n_estimators': 655.0, 'max_depth': 7.0, 'learning_rate': 0.057116598197387985, 'subsample': 0.7449481676452404}. Best is trial 12 with value: 0.19693626397188851.
# [I 2023-10-24 17:14:21,170] Trial 27 finished with value: 0.19755576311624887 and parameters: {'n_estimators': 837.0, 'max_depth': 9.0, 'learning_rate': 0.027917079460193672, 'subsample': 0.8163809755710691}. Best is trial 12 with value: 0.19693626397188851.
# [I 2023-10-24 17:15:23,386] Trial 28 finished with value: 0.19798547504122016 and parameters: {'n_estimators': 924.0, 'max_depth': 7.0, 'learning_rate': 0.05764264040527678, 'subsample': 0.8053296470421193}. Best is trial 12 with value: 0.19693626397188851.
# [I 2023-10-24 17:16:27,098] Trial 29 finished with value: 0.20629164647135817 and parameters: {'n_estimators': 679.0, 'max_depth': 9.0, 'learning_rate': 0.16925160625793623, 'subsample': 0.8646316938736055}. Best is trial 12 with value: 0.19693626397188851.
# [W 2023-10-24 17:17:01,200] Trial 30 failed with parameters: {'n_estimators': 596.0, 'max_depth': 7.0, 'learning_rate': 0.24550616479018011, 'subsample': 0.7301656732429453} because of the following error: KeyboardInterrupt().
# Traceback (most recent call last):
#   File "C:\Users\ishaa\AppData\Local\Programs\Python\Python310\lib\site-packages\optuna\study\_optimize.py", line 200, in _run_trial
#     value_or_values = func(trial)
#   File "C:\Users\ishaa\AppData\Local\Temp\ipykernel_27704\131333022.py", line 10, in objective
#     xgb_fit.fit(train_df[pitch_char_list + location_list + context_list], train_df["rv"])
#   File "C:\Users\ishaa\AppData\Local\Programs\Python\Python310\lib\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "C:\Users\ishaa\AppData\Local\Programs\Python\Python310\lib\site-packages\xgboost\sklearn.py", line 1025, in fit
#     self._Booster = train(
#   File "C:\Users\ishaa\AppData\Local\Programs\Python\Python310\lib\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "C:\Users\ishaa\AppData\Local\Programs\Python\Python310\lib\site-packages\xgboost\training.py", line 185, in train
#     bst.update(dtrain, i, obj)
#   File "C:\Users\ishaa\AppData\Local\Programs\Python\Python310\lib\site-packages\xgboost\core.py", line 1918, in update
#     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
# KeyboardInterrupt
# [W 2023-10-24 17:17:01,204] Trial 30 failed with value None.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[120], line 5
#       3 study = optuna.create_study()
#       4  # The optimization finishes after evaluating 1000 times or 3 seconds.
# ----> 5 study.optimize(objective, n_trials = 100)
#       6 print(time.time() - start_time)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\optuna\study\study.py:451, in Study.optimize(self, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#     348 def optimize(
#     349     self,
#     350     func: ObjectiveFuncType,
#    (...)
#     357     show_progress_bar: bool = False,
#     358 ) -> None:
#     359     """Optimize an objective function.
#     360
#     361     Optimization is done by choosing a suitable set of hyperparameter values from a given
#    (...)
#     449             If nested invocation of this method occurs.
#     450     """
# --> 451     _optimize(
#     452         study=self,
#     453         func=func,
#     454         n_trials=n_trials,
#     455         timeout=timeout,
#     456         n_jobs=n_jobs,
#     457         catch=tuple(catch) if isinstance(catch, Iterable) else (catch,),
#     458         callbacks=callbacks,
#     459         gc_after_trial=gc_after_trial,
#     460         show_progress_bar=show_progress_bar,
#     461     )
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\optuna\study\_optimize.py:66, in _optimize(study, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#      64 try:
#      65     if n_jobs == 1:
# ---> 66         _optimize_sequential(
#      67             study,
#      68             func,
#      69             n_trials,
#      70             timeout,
#      71             catch,
#      72             callbacks,
#      73             gc_after_trial,
#      74             reseed_sampler_rng=False,
#      75             time_start=None,
#      76             progress_bar=progress_bar,
#      77         )
#      78     else:
#      79         if n_jobs == -1:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\optuna\study\_optimize.py:163, in _optimize_sequential(study, func, n_trials, timeout, catch, callbacks, gc_after_trial, reseed_sampler_rng, time_start, progress_bar)
#     160         break
#     162 try:
# --> 163     frozen_trial = _run_trial(study, func, catch)
#     164 finally:
#     165     # The following line mitigates memory problems that can be occurred in some
#     166     # environments (e.g., services that use computing containers such as GitHub Actions).
#     167     # Please refer to the following PR for further details:
#     168     # https://github.com/optuna/optuna/pull/325.
#     169     if gc_after_trial:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\optuna\study\_optimize.py:251, in _run_trial(study, func, catch)
#     244         assert False, "Should not reach."
#     246 if (
#     247     frozen_trial.state == TrialState.FAIL
#     248     and func_err is not None
#     249     and not isinstance(func_err, catch)
#     250 ):
# --> 251     raise func_err
#     252 return frozen_trial
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\optuna\study\_optimize.py:200, in _run_trial(study, func, catch)
#     198 with get_heartbeat_thread(trial._trial_id, study._storage):
#     199     try:
# --> 200         value_or_values = func(trial)
#     201     except exceptions.TrialPruned as e:
#     202         # TODO(mamu): Handle multi-objective cases.
#     203         state = TrialState.PRUNED
#
# Cell In[118], line 10, in objective(trial)
#       2 def objective(trial):
#       4     xgb_fit = xgb.XGBRegressor(n_estimators = int(trial.suggest_float("n_estimators", 50, 1000, step = 1)),
#       5                                max_depth = int(trial.suggest_float("max_depth", 3, 10, step = 1)),
#       6                                learning_rate = trial.suggest_float("learning_rate", 0.005, 0.3),
#       7                                subsample = trial.suggest_float("subsample", 0.6, 1),
#       8                                tree_method = "hist")
# ---> 10     xgb_fit.fit(train_df[pitch_char_list + location_list + context_list], train_df["rv"])
#      12     pred = xgb_fit.predict(cv_df[pitch_char_list + location_list + context_list])
#      14     return((np.mean((pred - cv_df["rv"])**2))**0.5)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\xgboost\core.py:620, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     618 for k, arg in zip(sig.parameters, args):
#     619     kwargs[k] = arg
# --> 620 return func(**kwargs)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\xgboost\sklearn.py:1025, in XGBModel.fit(self, X, y, sample_weight, base_margin, eval_set, eval_metric, early_stopping_rounds, verbose, xgb_model, sample_weight_eval_set, base_margin_eval_set, feature_weights, callbacks)
#    1014     obj = None
#    1016 (
#    1017     model,
#    1018     metric,
#    (...)
#    1023     xgb_model, eval_metric, params, early_stopping_rounds, callbacks
#    1024 )
# -> 1025 self._Booster = train(
#    1026     params,
#    1027     train_dmatrix,
#    1028     self.get_num_boosting_rounds(),
#    1029     evals=evals,
#    1030     early_stopping_rounds=early_stopping_rounds,
#    1031     evals_result=evals_result,
#    1032     obj=obj,
#    1033     custom_metric=metric,
#    1034     verbose_eval=verbose,
#    1035     xgb_model=model,
#    1036     callbacks=callbacks,
#    1037 )
#    1039 self._set_evaluation_result(evals_result)
#    1040 return self
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\xgboost\core.py:620, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     618 for k, arg in zip(sig.parameters, args):
#     619     kwargs[k] = arg
# --> 620 return func(**kwargs)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\xgboost\training.py:185, in train(params, dtrain, num_boost_round, evals, obj, feval, maximize, early_stopping_rounds, evals_result, verbose_eval, xgb_model, callbacks, custom_metric)
#     183 if cb_container.before_iteration(bst, i, dtrain, evals):
#     184     break
# --> 185 bst.update(dtrain, i, obj)
#     186 if cb_container.after_iteration(bst, i, dtrain, evals):
#     187     break
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\xgboost\core.py:1918, in Booster.update(self, dtrain, iteration, fobj)
#    1915 self._validate_dmatrix_features(dtrain)
#    1917 if fobj is None:
# -> 1918     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#    1919                                             ctypes.c_int(iteration),
#    1920                                             dtrain.handle))
#    1921 else:
#    1922     pred = self.predict(dtrain, output_margin=True, training=True)
#
# KeyboardInterrupt:

# %%
def objective(hyperparam):
    cv_rmse = np.array([0, 0, 0, 0, 0], dtype = "float")
    # Initialize XGBoost
    xgb_fit = xgb.XGBRegressor(n_estimators = int(hyperparam["n_estimators"]), max_depth = int(hyperparam["max_depth"]), 
                               learning_rate = hyperparam["learning_rate"], subsample = hyperparam["subsample"])
    for i in range(5):
        train_iter_df = train_df[train_df["fold"] != (i + 1)]
        cv_df = train_df[train_df["fold"] == (i + 1)]
        
        # Fit on training data, predict on the left out fold, and calculate RMSE
        xgb_fit.fit(train_iter_df[["x1", "x2"]], train_iter_df["y"])
        pred = xgb_fit.predict(cv_df[["x1", "x2"]])
        cv_rmse[i] = (np.mean((pred - cv_df["y"])**2))**0.5
    
    print ("RMSE:", cv_rmse.mean())
    return {"loss": cv_rmse.mean(), "status": STATUS_OK }

# %%
# Look at predictions
print(np.mean((xgb_fit.predict(cv_df[pitch_char_list + location_list + context_list]) - cv_df["rv"])**2)**0.5)
print(cv_df["rv"].corr(pd.Series(xgb_fit.predict(cv_df[pitch_char_list + location_list + context_list]))))
# Out:
# 0.1989549236771565
# 0.01181250166912025

# %%
train_df["rv"].std()
# Out:
# 0.20066377712764996

# %%
cv_df["pred"] = xgb_fit.predict(cv_df[pitch_char_list + location_list + context_list])
test = cv_df.groupby(["player_name", "pitch_type"]).aggregate({"pred":"mean", "rv":"count"}).reset_index().sort_values("pred")

test[test["rv"] > 50]
# Out:
# C:\Users\ishaa\AppData\Local\Temp\ipykernel_27704\1015431315.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cv_df["pred"] = xgb_fit.predict(cv_df[pitch_char_list + location_list + context_list])
#            player_name pitch_type      pred   rv
# 202    Bleier, Richard         SI  0.013171   70
# 1176     Mantiply, Joe         SI  0.013698   66
# 664     García, Jarlín         FF  0.015448   86
# 445        Darvish, Yu         FC  0.015784  172
# 1104       Loup, Aaron         SI  0.015851   65
# ...                ...        ...       ...  ...
# 1819      Suter, Brent         CH  0.041027   57
# 1103       Loup, Aaron         FC  0.041812   55
# 47      Alvarado, José         FC  0.042267   58
# 619     Freeland, Kyle         KC  0.042730   82
# 1070  Leiter Jr., Mark         CH  0.043768   61
#
# [878 rows x 4 columns]

# %%
cv_df.groupby(["player_name", "pitch_type"])["rv"].mean().reset_index().sort_values("rv").head(n = 25)
# Out:
#               player_name pitch_type        rv
# 1493  Plassmeyer, Michael         CH -0.259186
# 1997        Weems, Jordan         CU -0.259186
# 1082  Liberatore, Matthew         SI -0.243833
# 553     Estrada, Jeremiah         CH -0.233658
# 614          Foster, Matt         CU -0.233658
# 116            Bard, Luke         CH -0.233658
# 1008      Knizner, Andrew         SL -0.233658
# 1424       Ortega, Oliver         FF -0.233658
# 1322        Moreta, Dauri         CH -0.233658
# 2078         Yates, Kirby         SL -0.233658
# 1576         Reyes, Pablo         FA -0.228481
# 1550       Ramirez, Yohan         FF -0.226302
# 101          Baez, Michel         SI -0.226302
# 1949           Vest, Will         SI -0.226302
# 23       Alcantara, Sandy         CU -0.226302
# 876         Houck, Tanner         SL -0.157202
# 1111           Lugo, Seth         CH -0.155999
# 44         Almonte, Yency         FF -0.137815
# 1658      Santana, Dennis         CH -0.137040
# 594          Fisher, Nate         CH -0.134348
# 437        Curry, Xzavion         CH -0.134045
# 1762   Stephenson, Robert         CU -0.129593
# 1272       Mikolas, Miles         CH -0.123327
# 653          Garcia, Luis         SI -0.117893
# 734        Gosselin, Phil         SL -0.115594
